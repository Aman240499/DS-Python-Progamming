# %% [markdown]
# # **dataframe**

# %% [markdown]
# 1.**creating** dataframe using list

# %%
list_data = [["sarang",23,"dhamangaon rly"],["aman",23,"dhamangaon rly"],["suraj",21,"hiwarkhad"],["rohit",25,"chalisgaon"]]
list_data
# Out:
# [['sarang', 23, 'dhamangaon rly'],
#  ['aman', 23, 'dhamangaon rly'],
#  ['suraj', 21, 'hiwarkhad'],
#  ['rohit', 25, 'chalisgaon']]

# %%
import pandas as pd
pd.DataFrame(list_data,)
# Out:
#         0   1               2
# 0  sarang  23  dhamangaon rly
# 1    aman  23  dhamangaon rly
# 2   suraj  21       hiwarkhad
# 3   rohit  25      chalisgaon

# %%
pd.DataFrame(list_data,columns = ["Name","Age","HomeTown"])
# Out:
#      Name  Age        HomeTown
# 0  sarang   23  dhamangaon rly
# 1    aman   23  dhamangaon rly
# 2   suraj   21       hiwarkhad
# 3   rohit   25      chalisgaon

# %% [markdown]
# 2.creating dataframe using **dictionary**

# %%
dict_data = {"name" : ["aman","sarang","umang","suraj"],
             "age" : [21,22,23,24],
             "iq" : [95,96,100,94]}
dict_data
# Out:
# {'name': ['aman', 'sarang', 'umang', 'suraj'],
#  'age': [21, 22, 23, 24],
#  'iq': [95, 96, 100, 94]}

# %%
students = pd.DataFrame(dict_data)
students
# Out:
#      name  age   iq
# 0    aman   21   95
# 1  sarang   22   96
# 2   umang   23  100
# 3   suraj   24   94

# %%
students.set_index("name",inplace = True)

# %%
students
# Out:
#         age   iq
# name
# aman     21   95
# sarang   22   96
# umang    23  100
# suraj    24   94

# %% [markdown]
# read_csv **file**

# %%
ipl_data = pd.read_csv("https://raw.githubusercontent.com/Aman240499/DS-Python-Progamming/main/IPL_Matches_2008_2022.csv")
ipl_data
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# # ***SHAPE***
#
# # TO CHECK THE rows and columns of the **data**

# %%
ipl_data.shape
# Out:
# (950, 20)

# %% [markdown]
# # **dtypes**
#
# to check data types of the columns

# %%
ipl_data.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %% [markdown]
# # **index**
#
# to check index of the data

# %%
ipl_data.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %% [markdown]
# # **columns**
#
# to check columns names of the data

# %%
ipl_data.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %% [markdown]
# # **values**
#
# we get 2d NUMPY Array

# %%
ipl_data.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
students
# Out:
#         age   iq
# name
# aman     21   95
# sarang   22   96
# umang    23  100
# suraj    24   94

# %%
students.index
# Out:
# Index(['aman', 'sarang', 'umang', 'suraj'], dtype='object', name='name')

# %%
students.shape
# Out:
# (4, 2)

# %%
students.columns
# Out:
# Index(['age', 'iq'], dtype='object')

# %%
students.dtypes
# Out:
# age    int64
# iq     int64
# dtype: object

# %% [markdown]
# # **Head**

# %%
ipl_data.head() #print first 5 records
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl_data.head(10)
# Out:
#         ID         City        Date Season  MatchNumber  \
# 0  1312200    Ahmedabad  2022-05-29   2022        Final
# 1  1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198      Kolkata  2022-05-25   2022   Eliminator
# 3  1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116       Mumbai  2022-05-22   2022           70
# 5  1304115       Mumbai  2022-05-21   2022           69
# 6  1304114       Mumbai  2022-05-20   2022           68
# 7  1304113       Mumbai  2022-05-19   2022           67
# 8  1304112  Navi Mumbai  2022-05-18   2022           66
# 9  1304111       Mumbai  2022-05-17   2022           65
#
#                          Team1                        Team2  \
# 0             Rajasthan Royals               Gujarat Titans
# 1  Royal Challengers Bangalore             Rajasthan Royals
# 2  Royal Challengers Bangalore         Lucknow Super Giants
# 3             Rajasthan Royals               Gujarat Titans
# ...

# %% [markdown]
# # **Tail**

# %%
ipl_data.tail() #last 5 records
# Out:
#          ID        City        Date   Season MatchNumber  \
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# ...

# %%
ipl_data.tail(10)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 940  335991  Chandigarh  2008-04-25  2007/08          10
# 941  335990   Hyderabad  2008-04-24  2007/08           9
# 942  335989     Chennai  2008-04-23  2007/08           8
# 943  335988   Hyderabad  2008-04-22  2007/08           7
# 944  335987      Jaipur  2008-04-21  2007/08           6
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 940              Kings XI Punjab               Mumbai Indians
# 941              Deccan Chargers             Rajasthan Royals
# 942          Chennai Super Kings               Mumbai Indians
# 943              Deccan Chargers             Delhi Daredevils
# ...

# %% [markdown]
# # **Sample**
#
# randomly take any data point

# %%
ipl_data.sample()
# Out:
#          ID     City        Date Season MatchNumber                  Team1  \
# 395  980975  Kolkata  2016-05-08   2016          38  Kolkata Knight Riders
#
#              Team2         Venue     TossWinner TossDecision SuperOver  \
# 395  Gujarat Lions  Eden Gardens  Gujarat Lions        field         N
#
#        WinningTeam    WonBy  Margin method Player_of_Match  \
# 395  Gujarat Lions  Wickets     5.0    NaN         P Kumar
#
#                                           Team1Players  \
# 395  ['RV Uthappa', 'G Gambhir', 'MK Pandey', 'SA Y...
#
#                                           Team2Players    Umpire1    Umpire2
# 395  ['DR Smith', 'BB McCullum', 'SK Raina', 'KD Ka...  M Erasmus  RJ Tucker

# %%
ipl_data.sample(10)
# Out:
#           ID        City        Date   Season MatchNumber  \
# 527   733979   Ahmedabad  2014-05-05     2014          25
# 165  1216528         NaN  2020-10-13  2020/21          29
# 353  1082610      Rajkot  2017-04-18     2017          20
# 276  1136598      Indore  2018-05-06     2018          38
# 733   501240     Chennai  2011-05-04     2011          43
# 2    1312198     Kolkata  2022-05-25     2022  Eliminator
# 501   734033  Chandigarh  2014-05-23     2014          52
# 479   829733        Pune  2015-04-18     2015          14
# 745   501229       Kochi  2011-04-27     2011          32
# 812   419127  Chandigarh  2010-03-27  2009/10          23
#
#                            Team1                        Team2  \
# 527             Rajasthan Royals        Kolkata Knight Riders
# 165          Chennai Super Kings          Sunrisers Hyderabad
# 353                Gujarat Lions  Royal Challengers Bangalore
# 276             Rajasthan Royals              Kings XI Punjab
# ...

# %% [markdown]
# # **info**

# %%
ipl_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %% [markdown]
# # **Describe**
#
# provides mathematical summary on the numerical values present in the data

# %%
ipl_data.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %% [markdown]
# # isnull / isna

# %%
#it returnts boolean values
ipl_data.isna()
# Out:
#         ID   City   Date  Season  MatchNumber  Team1  Team2  Venue  \
# 0    False  False  False   False        False  False  False  False
# 1    False  False  False   False        False  False  False  False
# 2    False  False  False   False        False  False  False  False
# 3    False  False  False   False        False  False  False  False
# 4    False  False  False   False        False  False  False  False
# ..     ...    ...    ...     ...          ...    ...    ...    ...
# 945  False  False  False   False        False  False  False  False
# 946  False  False  False   False        False  False  False  False
# 947  False  False  False   False        False  False  False  False
# 948  False  False  False   False        False  False  False  False
# 949  False  False  False   False        False  False  False  False
#
#      TossWinner  TossDecision  SuperOver  WinningTeam  WonBy  Margin  method  \
# 0         False         False      False        False  False   False    True
# ...

# %%
#to want value count
ipl_data.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %% [markdown]
# # Duplicated
#
# it will check duplicated records

# %%
ipl_data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Length: 950, dtype: bool

# %%
ipl_data.duplicated().sum()
# Out:
# 0

# %%
students
# Out:
#         age   iq
# name
# aman     21   95
# sarang   22   96
# umang    23  100
# suraj    24   94

# %% [markdown]
# # **rename**

# %%
info = pd.DataFrame({"name" : ["aman","pratik","suraj","anushree","saloni","radika"],
                    "iq" :[91,92,93,94,95,96],
                     "age" : [21,22,23,24,25,26],
                     "salary" :[7.2,7.1,6.0,6.5,6.7,9.5]})
info
# Out:
#        name  iq  age  salary
# 0      aman  91   21     7.2
# 1    pratik  92   22     7.1
# 2     suraj  93   23     6.0
# 3  anushree  94   24     6.5
# 4    saloni  95   25     6.7
# 5    radika  96   26     9.5

# %% [markdown]
# # ***rename***
#
# renaming the column name and row names

# %%
info.rename(columns = {"salary" : "LPA"},inplace = True)
info
# Out:
#        name  iq  age  LPA
# 0      aman  91   21  7.2
# 1    pratik  92   22  7.1
# 2     suraj  93   23  6.0
# 3  anushree  94   24  6.5
# 4    saloni  95   25  6.7
# 5    radika  96   26  9.5

# %%
info.rename(index = {0:"zero",1:"first",2:"secound",3 :"third",4 :"fourth", 5 :"fifth"},inplace = True)
info
# Out:
#              name  iq  age  LPA
# zero         aman  91   21  7.2
# first      pratik  92   22  7.1
# secound     suraj  93   23  6.0
# third    anushree  94   24  6.5
# fourth     saloni  95   25  6.7
# fifth      radika  96   26  9.5

# %%
employee = pd.DataFrame({"iq" : [100,90,80,120,0,0],
            "marks" : [80,70,100,50,0,0],
            "package" : [10,7,14,2,0,0]})
employee
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2   80    100       14
# 3  120     50        2
# 4    0      0        0
# 5    0      0        0

# %% [markdown]
# # **MATHEMATICAL OPERATION**

# %% [markdown]
# # **SUM**

# %%
#columns wise addition
employee.sum()
# Out:
# iq         390
# marks      300
# package     33
# dtype: int64

# %%
#row wise addition
employee.sum(axis = 1)
# Out:
# 0    190
# 1    167
# 2    194
# 3    172
# 4      0
# 5      0
# dtype: int64

# %%
#provides mathematical summary on the numerical values present in the data and concatination will happen'''
ipl_data.sum()
# Out:
# <ipython-input-353-dc526a69d69e>:2: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ipl_data.sum()
# ID                                                      788960985
# Date            2022-05-292022-05-272022-05-252022-05-242022-0...
# Season          2022202220222022202220222022202220222022202220...
# MatchNumber     FinalQualifier 2EliminatorQualifier 1706968676...
# Team1           Rajasthan RoyalsRoyal Challengers BangaloreRoy...
# Team2           Gujarat TitansRajasthan RoyalsLucknow Super Gi...
# Venue           Narendra Modi Stadium, AhmedabadNarendra Modi ...
# TossWinner      Rajasthan RoyalsRajasthan RoyalsLucknow Super ...
# TossDecision    batfieldfieldfieldbatfieldbatbatbatfieldfieldb...
# ...

# %%
ipl_data.sum(axis = 1)
# Out:
# <ipython-input-354-5534a9d9b0b3>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   ipl_data.sum(axis = 1)
# 0      1312207.0
# 1      1312206.0
# 2      1312212.0
# 3      1312204.0
# 4      1304121.0
#          ...
# 945     335991.0
# 946     335990.0
# 947     335993.0
# 948     336016.0
# 949     336122.0
# Length: 950, dtype: float64

# %% [markdown]
# # **mean**
#
# average of all the data

# %%
employee.mean()
# Out:
# iq         65.0
# marks      50.0
# package     5.5
# dtype: float64

# %%
employee.mean(axis = 1)
# Out:
# 0    63.333333
# 1    55.666667
# 2    64.666667
# 3    57.333333
# 4     0.000000
# 5     0.000000
# dtype: float64

# %%
ipl_data.mean() #it will only take integer columns
# Out:
# <ipython-input-357-93c17e93994d>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ipl_data.mean() #it will only take integer columns
# ID        830485.247368
# Margin        17.056867
# dtype: float64

# %% [markdown]
# #median

# %%
employee.median()
# Out:
# iq         85.0
# marks      60.0
# package     4.5
# dtype: float64

# %%
employee.median(axis = 1)
# Out:
# 0    80.0
# 1    70.0
# 2    80.0
# 3    50.0
# 4     0.0
# 5     0.0
# dtype: float64

# %% [markdown]
# # **varience (var)**
#
# how much data is spread

# %%
employee.var()
# Out:
# iq         2710.0
# marks      1760.0
# package      33.5
# dtype: float64

# %%
employee.var(axis = 1)
# Out:
# 0    2233.333333
# 1    1876.333333
# 2    2025.333333
# 3    3521.333333
# 4       0.000000
# 5       0.000000
# dtype: float64

# %% [markdown]
# # **standarddeviation (std)**

# %%
employee.std()
# Out:
# iq         52.057660
# marks      41.952354
# package     5.787918
# dtype: float64

# %%
employee.std(axis = 1)
# Out:
# 0    47.258156
# 1    43.316663
# 2    45.003704
# 3    59.340823
# 4     0.000000
# 5     0.000000
# dtype: float64

# %% [markdown]
# # **min**

# %%
employee.min()
# Out:
# iq         0
# marks      0
# package    0
# dtype: int64

# %%
employee.min(axis = 1)
# Out:
# 0    10
# 1     7
# 2    14
# 3     2
# 4     0
# 5     0
# dtype: int64

# %% [markdown]
# # **max**

# %%
employee.max()
# Out:
# iq         120
# marks      100
# package     14
# dtype: int64

# %%
employee.max(axis = 1)
# Out:
# 0    100
# 1     90
# 2    100
# 3    120
# 4      0
# 5      0
# dtype: int64

# %% [markdown]
# # **selecting columns from dataframe**

# %%
ipl_data.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
#single column
ipl_data["City"]
# Out:
# 0       Ahmedabad
# 1       Ahmedabad
# 2         Kolkata
# 3         Kolkata
# 4          Mumbai
#           ...
# 945       Kolkata
# 946        Mumbai
# 947         Delhi
# 948    Chandigarh
# 949     Bangalore
# Name: City, Length: 950, dtype: object

# %%
type(ipl_data["City"])
# Out:
# pandas.core.series.Series

# %%
#multiple columns
min_data = ipl_data[["City","Date","Team1","Team2"]]
min_data
# Out:
#            City        Date                        Team1  \
# 0     Ahmedabad  2022-05-29             Rajasthan Royals
# 1     Ahmedabad  2022-05-27  Royal Challengers Bangalore
# 2       Kolkata  2022-05-25  Royal Challengers Bangalore
# 3       Kolkata  2022-05-24             Rajasthan Royals
# 4        Mumbai  2022-05-22          Sunrisers Hyderabad
# ..          ...         ...                          ...
# 945     Kolkata  2008-04-20        Kolkata Knight Riders
# 946      Mumbai  2008-04-20               Mumbai Indians
# 947       Delhi  2008-04-19             Delhi Daredevils
# 948  Chandigarh  2008-04-19              Kings XI Punjab
# 949   Bangalore  2008-04-18  Royal Challengers Bangalore
#
#                            Team2
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2           Lucknow Super Giants
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ..                           ...
# 945              Deccan Chargers
# ...

# %%
type(min_data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # **selecting rows from dataframe**
#
# iloc - searches using index positions
#
# loc - searches using index labels

# %% [markdown]
# # **1.iloc**

# %%
#single data
ipl_data.iloc[0]
# Out:
# ID                                                           1312200
# City                                                       Ahmedabad
# Date                                                      2022-05-29
# Season                                                          2022
# MatchNumber                                                    Final
# Team1                                               Rajasthan Royals
# Team2                                                 Gujarat Titans
# Venue                               Narendra Modi Stadium, Ahmedabad
# TossWinner                                          Rajasthan Royals
# TossDecision                                                     bat
# SuperOver                                                          N
# WinningTeam                                           Gujarat Titans
# WonBy                                                        Wickets
# Margin                                                           7.0
# ...

# %%
type(ipl_data.iloc[0])
# Out:
# pandas.core.series.Series

# %%
#multiple rows
ipl_data.iloc[0:5]
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
type(ipl_data.iloc[0:5])
# Out:
# pandas.core.frame.DataFrame

# %%
#we want alternate matches between 10,30
ipl_data.iloc[10:31:2]
# Out:
#          ID         City        Date Season MatchNumber  \
# 10  1304110  Navi Mumbai  2022-05-16   2022          64
# 12  1304108       Mumbai  2022-05-15   2022          62
# 14  1304106       Mumbai  2022-05-13   2022          60
# 16  1304104  Navi Mumbai  2022-05-11   2022          58
# 18  1304102  Navi Mumbai  2022-05-09   2022          56
# 20  1304100       Mumbai  2022-05-08   2022          54
# 22  1304098       Mumbai  2022-05-07   2022          52
# 24  1304096       Mumbai  2022-05-05   2022          50
# 26  1304094  Navi Mumbai  2022-05-03   2022          48
# 28  1304092         Pune  2022-05-01   2022          46
# 30  1304090  Navi Mumbai  2022-04-30   2022          44
#
#                           Team1                        Team2  \
# 10               Delhi Capitals                 Punjab Kings
# 12          Chennai Super Kings               Gujarat Titans
# 14                 Punjab Kings  Royal Challengers Bangalore
# ...

# %%
#fancy indexing
#we passing data points which we want
ipl_data.iloc[[4,5,50,200]]
# Out:
#           ID       City        Date Season MatchNumber                Team1  \
# 4    1304116     Mumbai  2022-05-22   2022          70  Sunrisers Hyderabad
# 5    1304115     Mumbai  2022-05-21   2022          69       Delhi Capitals
# 50   1304070     Mumbai  2022-04-14   2022          24       Gujarat Titans
# 200  1178429  Bengaluru  2019-05-04   2019          54  Sunrisers Hyderabad
#
#                            Team2                               Venue  \
# 4                   Punjab Kings            Wankhede Stadium, Mumbai
# 5                 Mumbai Indians            Wankhede Stadium, Mumbai
# 50              Rajasthan Royals  Dr DY Patil Sports Academy, Mumbai
# 200  Royal Challengers Bangalore               M.Chinnaswamy Stadium
#
#                       TossWinner TossDecision SuperOver  \
# 4            Sunrisers Hyderabad          bat         N
# 5                 Mumbai Indians        field         N
# 50              Rajasthan Royals        field         N
# ...

# %% [markdown]
# # **2.loc**

# %%
students
# Out:
#         age   iq
# name
# aman     21   95
# sarang   22   96
# umang    23  100
# suraj    24   94

# %%
students.loc["aman"]
# Out:
# age    21
# iq     95
# Name: aman, dtype: int64

# %%
students.loc["aman":"umang"]
# Out:
#         age   iq
# name
# aman     21   95
# sarang   22   96
# umang    23  100

# %%
students.loc["aman":"suraj":2]
# Out:
#        age   iq
# name
# aman    21   95
# umang   23  100

# %%
students.loc[["aman","sarang","suraj"]]
# Out:
#         age  iq
# name
# aman     21  95
# sarang   22  96
# suraj    24  94

# %% [markdown]
# # **selecting both rows and columns**

# %%
ipl_data.iloc[0:5,1:4]
# Out:
#         City        Date Season
# 0  Ahmedabad  2022-05-29   2022
# 1  Ahmedabad  2022-05-27   2022
# 2    Kolkata  2022-05-25   2022
# 3    Kolkata  2022-05-24   2022
# 4     Mumbai  2022-05-22   2022

# %% [markdown]
# # **pandas filtering**

# %%
new_df = ipl_data[ipl_data["MatchNumber"] == "Final"]
new_df
# Out:
#           ID          City        Date   Season MatchNumber  \
# 0    1312200     Ahmedabad  2022-05-29     2022       Final
# 74   1254117         Dubai  2021-10-15     2021       Final
# 134  1237181           NaN  2020-11-10  2020/21       Final
# 194  1181768     Hyderabad  2019-05-12     2019       Final
# 254  1136620        Mumbai  2018-05-27     2018       Final
# 314  1082650     Hyderabad  2017-05-21     2017       Final
# 373   981019     Bangalore  2016-05-29     2016       Final
# 433   829823       Kolkata  2015-05-24     2015       Final
# 492   734049     Bangalore  2014-06-01     2014       Final
# 552   598073       Kolkata  2013-05-26     2013       Final
# 628   548381       Chennai  2012-05-27     2012       Final
# 702   501271       Chennai  2011-05-28     2011       Final
# 775   419165        Mumbai  2010-04-25  2009/10       Final
# 835   392239  Johannesburg  2009-05-24     2009       Final
# 892   336040        Mumbai  2008-06-01  2007/08       Final
#
# ...

# %%
#winning team with season
new_df[["Season","WinningTeam"]]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
#we can do in one line
ipl_data[ipl_data["MatchNumber"] == "Final"][["Season","WinningTeam"]]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
ipl = ipl_data["SuperOver"] == "Y"
ipl
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Name: SuperOver, Length: 950, dtype: bool

# %%
ipl.value_counts()
# Out:
# False    936
# True      14
# Name: SuperOver, dtype: int64

# %%
ipl_data.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
ipl_data["SuperOver"].value_counts()
# Out:
# N    932
# Y     14
# Name: SuperOver, dtype: int64

# %%
ipl_data[ipl_data["SuperOver"] == "Y"]
# Out:
#           ID       City        Date   Season MatchNumber  \
# 114  1254077    Chennai  2021-04-25     2021          20
# 158  1216512  Abu Dhabi  2020-10-18  2020/21          35
# 159  1216517        NaN  2020-10-18  2020/21          36
# 184  1216547        NaN  2020-09-28  2020/21          10
# 192  1216493        NaN  2020-09-20  2020/21           2
# 203  1178426     Mumbai  2019-05-02     2019          51
# 244  1175365      Delhi  2019-03-30     2019          10
# 339  1082625     Rajkot  2017-04-29     2017          35
# 474   829741  Ahmedabad  2015-04-21     2015          18
# 533   729315  Abu Dhabi  2014-04-29     2014          19
# 608   598017  Bangalore  2013-04-16     2013          21
# 621   598004  Hyderabad  2013-04-07     2013           7
# 819   419121    Chennai  2010-03-21  2009/10          16
# 883   392190  Cape Town  2009-04-23     2009          10
#
#                            Team1                        Team2  \
# ...

# %%
#how many matches csk won in kolkata
ipl_data[(ipl_data["WinningTeam"] == "Chennai Super Kings") & (ipl_data["City"] == "Kolkata" )]
# Out:
#           ID     City        Date   Season MatchNumber                  Team1  \
# 224  1178404  Kolkata  2019-04-14     2019          29  Kolkata Knight Riders
# 602   598022  Kolkata  2013-04-20     2013          26  Kolkata Knight Riders
# 641   548368  Kolkata  2012-05-14     2012          63  Kolkata Knight Riders
# 827   419113  Kolkata  2010-03-16  2009/10           8  Kolkata Knight Riders
# 908   336025  Kolkata  2008-05-18  2007/08          41  Kolkata Knight Riders
#
#                    Team2         Venue             TossWinner TossDecision  \
# 224  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 602  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
# 641  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 827  Chennai Super Kings  Eden Gardens    Chennai Super Kings          bat
# 908  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
#
# ...

# %%
#player_of the match is virat kohli
msdhoni = ipl_data[ipl_data["Player_of_Match"] == "MS Dhoni"]
msdhoni
# Out:
#           ID           City        Date   Season        MatchNumber  \
# 204  1178425        Chennai  2019-05-01     2019                 50
# 229  1178400         Jaipur  2019-04-11     2019                 25
# 243  1175367        Chennai  2019-03-31     2019                 12
# 290  1136584      Bengaluru  2018-04-25     2018                 24
# 348  1082615           Pune  2017-04-22     2017                 24
# 380   981005  Visakhapatnam  2016-05-21     2016                 53
# 498   734035      Bangalore  2014-05-24     2014                 53
# 564   598062        Chennai  2013-05-14     2013                 64
# 586   598038           Pune  2013-04-30     2013                 42
# 594   598030        Chennai  2013-04-25     2013                 34
# 630   548379      Bangalore  2012-05-23     2012  Elimination Final
# 720   501253        Chennai  2011-05-12     2011                 56
# 781   419159     Dharamsala  2010-04-18  2009/10                 54
# ...

# %%
msdhoni.shape
# Out:
# (17, 20)

# %%
ipl_data[(ipl_data["City"] == "Chennai")  & (ipl_data["Player_of_Match"] == "MS Dhoni")][["TossWinner"]]
# Out:
#               TossWinner
# 204       Delhi Capitals
# 243     Rajasthan Royals
# 564  Chennai Super Kings
# 594  Sunrisers Hyderabad
# 720  Chennai Super Kings

# %%
#how many matches toss winner is match winner
ipl_data["TossWinner"] == ipl_data["WinningTeam"]
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948     True
# 949    False
# Length: 950, dtype: bool

# %%
ipl_data[ipl_data["TossWinner"] == ipl_data["WinningTeam"]]
# Out:
#           ID         City        Date   Season  MatchNumber  \
# 1    1312199    Ahmedabad  2022-05-27     2022  Qualifier 2
# 3    1312197      Kolkata  2022-05-24     2022  Qualifier 1
# 5    1304115       Mumbai  2022-05-21     2022           69
# 8    1304112  Navi Mumbai  2022-05-18     2022           66
# 11   1304109       Mumbai  2022-05-15     2022           63
# ..       ...          ...         ...      ...          ...
# 935   335996    Bangalore  2008-04-28  2007/08           15
# 937   335994       Mumbai  2008-04-27  2007/08           14
# 939   335992    Bangalore  2008-04-26  2007/08           12
# 941   335990    Hyderabad  2008-04-24  2007/08            9
# 948   335983   Chandigarh  2008-04-19  2007/08            2
#
#                            Team1                  Team2  \
# 1    Royal Challengers Bangalore       Rajasthan Royals
# 3               Rajasthan Royals         Gujarat Titans
# 5                 Delhi Capitals         Mumbai Indians
# ...

# %%
ipl_data[ipl_data["TossWinner"] == ipl_data["WinningTeam"]].shape[0]
# Out:
# 489

# %%
ipl_data.shape[0]
# Out:
# 950

# %%
a = ipl_data[ipl_data["TossWinner"] == ipl_data["WinningTeam"]].shape[0]
b = ipl_data.shape[0]

winning_percentage = (a/b)*100
winning_percentage
# Out:
# 51.473684210526315

# %% [markdown]
# # **Droping na values**

# %%
ipl_data.isna().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
ipl_data = ipl_data.drop(columns = ["method"])
ipl_data
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl_data.isna().sum()
# Out:
# ID                  0
# City               51
# Date                0
# Season              0
# MatchNumber         0
# Team1               0
# Team2               0
# Venue               0
# TossWinner          0
# TossDecision        0
# SuperOver           4
# WinningTeam         4
# WonBy               0
# Margin             18
# Player_of_Match     4
# Team1Players        0
# Team2Players        0
# Umpire1             0
# Umpire2             0
# dtype: int64

# %%
#droping na records
ipl_data = ipl_data.dropna()

# %%
ipl_data.isna().sum()
# Out:
# ID                 0
# City               0
# Date               0
# Season             0
# MatchNumber        0
# Team1              0
# Team2              0
# Venue              0
# TossWinner         0
# TossDecision       0
# SuperOver          0
# WinningTeam        0
# WonBy              0
# Margin             0
# Player_of_Match    0
# Team1Players       0
# Team2Players       0
# Umpire1            0
# Umpire2            0
# dtype: int64

# %% [markdown]
# # **Important DataFrame Functions**

# %% [markdown]
# # **astype**
#
# it changes datatype of given columns

# %%
 ipl_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 884 entries, 0 to 949
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               884 non-null    int64
#  1   City             884 non-null    object
#  2   Date             884 non-null    object
#  3   Season           884 non-null    object
#  4   MatchNumber      884 non-null    object
#  5   Team1            884 non-null    object
#  6   Team2            884 non-null    object
#  7   Venue            884 non-null    object
#  8   TossWinner       884 non-null    object
#  9   TossDecision     884 non-null    object
#  10  SuperOver        884 non-null    object
#  11  WinningTeam      884 non-null    object
#  12  WonBy            884 non-null    object
#  13  Margin           884 non-null    float64
#  14  Player_of_Match  884 non-null    object
#  15  Team1Players     884 non-null    object
# ...

# %%
ipl_data["Margin"].astype("int64")
# Out:
# 0        7
# 1        7
# 2       14
# 3        7
# 4        5
#       ...
# 945      5
# 946      5
# 947      9
# 948     33
# 949    140
# Name: Margin, Length: 884, dtype: int64

# %%
ipl_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 884 entries, 0 to 949
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               884 non-null    int64
#  1   City             884 non-null    object
#  2   Date             884 non-null    object
#  3   Season           884 non-null    object
#  4   MatchNumber      884 non-null    object
#  5   Team1            884 non-null    object
#  6   Team2            884 non-null    object
#  7   Venue            884 non-null    object
#  8   TossWinner       884 non-null    object
#  9   TossDecision     884 non-null    object
#  10  SuperOver        884 non-null    object
#  11  WinningTeam      884 non-null    object
#  12  WonBy            884 non-null    object
#  13  Margin           884 non-null    float64
#  14  Player_of_Match  884 non-null    object
#  15  Team1Players     884 non-null    object
# ...

# %%
ipl_data["Margin"] = ipl_data["Margin"].astype("int64")
ipl_data.dtypes
# Out:
# <ipython-input-410-175362dbb800>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl_data["Margin"] = ipl_data["Margin"].astype("int64")
# ID                  int64
# City               object
# Date               object
# Season             object
# MatchNumber        object
# Team1              object
# Team2              object
# Venue              object
# TossWinner         object
# TossDecision       object
# SuperOver          object
# WinningTeam        object
# WonBy              object
# Margin              int64
# Player_of_Match    object
# Team1Players       object
# Team2Players       object
# Umpire1            object
# Umpire2            object
# dtype: object

# %%
# we will convert season datatype to category data type
ipl_data["Season"] = ipl_data["Season"].astype("category")
ipl_data
# Out:
# <ipython-input-411-3222e565dc1a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl_data["Season"] = ipl_data["Season"].astype("category")
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# ...

# %%
ipl_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 884 entries, 0 to 949
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               884 non-null    int64
#  1   City             884 non-null    object
#  2   Date             884 non-null    object
#  3   Season           884 non-null    category
#  4   MatchNumber      884 non-null    object
#  5   Team1            884 non-null    object
#  6   Team2            884 non-null    object
#  7   Venue            884 non-null    object
#  8   TossWinner       884 non-null    object
#  9   TossDecision     884 non-null    object
#  10  SuperOver        884 non-null    object
#  11  WinningTeam      884 non-null    object
#  12  WonBy            884 non-null    object
#  13  Margin           884 non-null    int64
#  14  Player_of_Match  884 non-null    object
#  15  Team1Players     884 non-null    object
# ...
